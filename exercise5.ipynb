# %% [markdown]
# <a href="https://colab.research.google.com/github/aalimanadan0/CCINCOML_EXERCISES_COM23P/blob/main/Copy_of_exercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 5

# %% [markdown]
# 1. Compute the average
#
# My electricity bills for the last three months have been 23, 32 and 64.
#
# - What is the average monthly electricity bill over the three month period?
#
# - Write an expression to calculate the mean, and use print() to view the result.

# %%
#Define the electricity bills for the last three months
bill1 = 23
bill2 = 32
bill3 = 64

#Calculate the average
average = (bill1 + bill2 + bill3) / 3

#Print the result
print("The average monthly electricity bill over the three month perod is:", average)
# Out:
# The average monthly electricity bill over the three month perod is: 39.666666666666664

# %% [markdown]
# 2. Create a condition
#
# The code below calculates the population densities of Rio de Janeiro and San Francisco.
#
# Write a code to compare these densities. Is the population of San Francisco more dense than that of Rio de Janeiro? Print True if it is and False if not.

# %%
sf_population, sf_area = 864816, 231.89
rio_population, rio_area = 6453682, 486.5

san_francisco_pop_density = sf_population/sf_area
rio_de_janeiro_pop_density = rio_population/rio_area

# Write code that prints True if San Francisco is denser than Rio, and False otherwise

# Compare population densilities
is_sf_denser = san_francisco_pop_density > rio_de_janeiro_pop_density

# Print the result
print(is_sf_denser)
# Out:
# False

# %% [markdown]
# 3. Fix the error
#
# The line of code below will cause a SyntaxError, thanks to the misuse of quotation marks.
#
# - First run it with Test Run to view the error message.
# - Then resolve the problem so that the quote (from Henry Ford(opens in a new tab)) is correctly assigned to the variable ford_quote.

# %%
# TODO: Fix this string!
ford_quote = "Whether you think you can, or you think you can't you're right."

#Corrected ford_quote variable with the quote from Henry Ford

ford_quote = "Whether you think you can, or you think you can't you're right."
# Print the corrected quote to verify
print(ford_quote)
# Out:
# Whether you think you can, or you think you can't you're right.

# %% [markdown]
# 4. Write a server log message
#
# You’ll be provided with example data for a user, the time of their visit and the site they accessed. You should use the variables provided and the techniques you’ve learned to print a log message like this one (with the username, url, and timestamp replaced with values from the appropriate variables):

# %%
username = "Kinari"
timestamp = "04:50"
url = "http://petshop.com/pets/mammals/cats"

# TODO: print a log message using the variables above.
# The message should have the same format as this one:
# "Yogesh accessed the site http://petshop.com/pets/reptiles/pythons at 16:20."
log_message = f"{username} accessed the site {url} at {timestamp}."
print(log_message)

username = "Yogesh"
timestamp = "16:20"
url = "http://petshop.com/pets/reptiles/pythons"

# TODO: print a log message using the variables above.
# The message should have the same format as this one:
# "Yogesh accessed the site http://petshop.com/pets/reptiles/pythons at 16:20."
log_message = f"{username} accessed the site {url} at {timestamp}."
print(log_message)
# Out:
# Kinari accessed the site http://petshop.com/pets/mammals/cats at 04:50.
# Yogesh accessed the site http://petshop.com/pets/reptiles/pythons at 16:20.

# %% [markdown]
# 5. Use string concatenation and the `len()` function to find the length of a certain movie star's actual full name. Store that length in the name_length variable. Don't forget that there are spaces in between the different parts of a name!

# %%
given_name = "William"
middle_names = "Bradley"
family_name = "Pitt"

# Concatenate the different parts of the name with spaces in between
full_name = given_name + " " + middle_names + " " + family_name

# Calculate the length of the full name
name_length = len(full_name)

print(f"The length of the name '{full_name}' is {name_length}.")
# Out:
# The length of the name 'William Bradley Pitt' is 20.

# %% [markdown]
# 6. Type Conversion
#
# - You will need to change the types of the input and output data in order to get the result you want.
#
# - Calculate and print the total sales for the week from the data provided.
#
# - Print out a string of the form "This week's total sales: xxx", where xxx will be the actual total of all the numbers. You’ll need to change the type of the input data in order to calculate that total.

# %%
mon_sales = "121"
tues_sales = "105"
wed_sales = "110"
thurs_sales = "98"
fri_sales = "95"

#TODO: Print a string with this format: This week's total sales: xxx
# You will probably need to write some lines of code before the print statement.


sales_data = {
    "Monday": "1234.50",
    "Tuesday": "2345.67",
    "Wednesday": "3456.78",
    "Thursday": "4567.89",
    "Friday": "5678.90",
    "Saturday": "6789.01",
    "Sunday": "7890.12"
}

# Initialize the total sales variable
total_sales = 0

# Loop through the sales data and add up the sales figures
for day, sales in sales_data.items():
    # Convert the sales figure to a float and add it to the total
    total_sales += float(sales)

# Print out a string with the total sales
print(f"This week's total sales: {total_sales:.2f}")
# Out:
# This week's total sales: 31962.87

# %% [markdown]
# 7. String methods
#
# Below, we have a string variable that contains the first verse of the poem, If by Rudyard Kipling(opens in a new tab)

# %%
verse = "If you can keep your head when all about you\n  Are losing theirs and blaming it on you,\nIf you can trust yourself when all men doubt you,\n  But make allowance for their doubting too;\nIf you can wait and not be tired by waiting,\n  Or being lied about, don’t deal in lies,\nOr being hated, don’t give way to hating,\n  And yet don’t look too good, nor talk too wise:"
print(verse)

print(verse.upper())
print(verse.lower())
print(verse.strip())
print(verse.replace("If", "When"))
print(verse.split())
# Out:
# If you can keep your head when all about you
#   Are losing theirs and blaming it on you,
# If you can trust yourself when all men doubt you,
#   But make allowance for their doubting too;
# If you can wait and not be tired by waiting,
#   Or being lied about, don’t deal in lies,
# Or being hated, don’t give way to hating,
#   And yet don’t look too good, nor talk too wise:
# IF YOU CAN KEEP YOUR HEAD WHEN ALL ABOUT YOU
#   ARE LOSING THEIRS AND BLAMING IT ON YOU,
# IF YOU CAN TRUST YOURSELF WHEN ALL MEN DOUBT YOU,
#   BUT MAKE ALLOWANCE FOR THEIR DOUBTING TOO;
# IF YOU CAN WAIT AND NOT BE TIRED BY WAITING,
#   OR BEING LIED ABOUT, DON’T DEAL IN LIES,
# OR BEING HATED, DON’T GIVE WAY TO HATING,
#   AND YET DON’T LOOK TOO GOOD, NOR TALK TOO WISE:
# if you can keep your head when all about you
#   are losing theirs and blaming it on you,
# if you can trust yourself when all men doubt you,
#   but make allowance for their doubting too;
# if you can wait and not be tired by waiting,
#   or being lied about, don’t deal in lies,
# or being hated, don’t give way to hating,
#   and yet don’t look too good, nor talk too wise:
# If you can keep your head when all about you
#   Are losing theirs and blaming it on you,
# If you can trust yourself when all men doubt you,
#   But make allowance for their doubting too;
# If you can wait and not be tired by waiting,
#   Or being lied about, don’t deal in lies,
# Or being hated, don’t give way to hating,
#   And yet don’t look too good, nor talk too wise:
# When you can keep your head when all about you
#   Are losing theirs and blaming it on you,
# When you can trust yourself when all men doubt you,
#   But make allowance for their doubting too;
# When you can wait and not be tired by waiting,
#   Or being lied about, don’t deal in lies,
# Or being hated, don’t give way to hating,
#   And yet don’t look too good, nor talk too wise:
# ['If', 'you', 'can', 'keep', 'your', 'head', 'when', 'all', 'about', 'you', 'Are', 'losing', 'theirs', 'and', 'blaming', 'it', 'on', 'you,', 'If', 'you', 'can', 'trust', 'yourself', 'when', 'all', 'men', 'doubt', 'you,', 'But', 'make', 'allowance', 'for', 'their', 'doubting', 'too;', 'If', 'you', 'can', 'wait', 'and', 'not', 'be', 'tired', 'by', 'waiting,', 'Or', 'being', 'lied', 'about,', 'don’t', 'deal', 'in', 'lies,', 'Or', 'being', 'hated,', 'don’t', 'give', 'way', 'to', 'hating,', 'And', 'yet', 'don’t', 'look', 'too', 'good,', 'nor', 'talk', 'too', 'wise:']

# %% [markdown]
# What is the length of the string variable verse?

# %%
verse = "If you can keep your head when all about you\n  Are losing theirs and blaming it on you,\nIf you can trust yourself when all men doubt you,\n  But make allowance for their doubting too;\nIf you can wait and not be tired by waiting,\n  Or being lied about, don’t deal in lies,\nOr being hated, don’t give way to hating,\n  And yet don’t look too good, nor talk too wise:"

# Get the length of the string
length = len(verse)

# Print out the length
print(f"The length of the string variable 'verse' is {length} characters.")
# Out:
# The length of the string variable 'verse' is 362 characters.

# %% [markdown]
# What is the count of occurrences of the word 'you' in the verse?

# %%
# Count the number of occurrences of the word 'you' in the lowercase version of the verse
count = verse.lower().count('you')

# Print out the result
print(f"The word 'you' appears {count} times in the verse (case-insensitive).")
# Out:
# The word 'you' appears 8 times in the verse (case-insensitive).

# %% [markdown]
# What is the index of the first occurrence of the word 'head' in verse?

# %%
verse = "If you can keep your head when all about you\n  Are losing theirs and blaming it on you,\nIf you can trust yourself when all men doubt you,\n  But make allowance for their doubting too;\nIf you can wait and not be tired by waiting,\n  Or being lied about, don’t deal in lies,\nOr being hated, don’t give way to hating,\n  And yet don’t look too good, nor talk too wise:"

# Find the index of the first occurrence of the word 'head' in the verse
index = verse.find('head')

# Print out the result
print(f"The index of the first occurrence of the word 'head' in the verse is {index}.")
# Out:
# The index of the first occurrence of the word 'head' in the verse is 21.

# %% [markdown]
# 8. Which Prize?
#
# - Write an if statement that lets a competitor know which of these prizes they won based on the number of points they scored, which is stored in the integer variable points.
#
# |   Points| Prize  |
# |---|---|
# |  1 - 50  |  Candy |
# |  51 - 150 |  Chocolate |
# |  151 - 200 | Sports Car  |
# |  201 - 250 | Mansion  |
#
#
#  - In your if statement, assign the result variable to a string holding the appropriate message based on the value of points. If they've won a prize, the message should state "Congratulations! You won a [prize name]!" with the prize name. If there's no prize, the message should state "Oh dear, no prize this time."

# %%
points = 120
result = ""

if points >= 1 and points <= 50:
    result = f"Congratulations! You won a Candy!"
elif points >= 51 and points <= 150:
    result = f"Congratulations! You won a Chocolate!"
elif points >= 151 and points <= 200:
    result = f"Congratulations! You won a Sports Car!"
elif points >= 201 and points <= 250:
    result = f"Congratulations! You won a Mansion!"
else:
    result = "Oh dear, no prize this time."

print(result)
# Out:
# Congratulations! You won a Chocolate!

# %% [markdown]
# 9. Guess My Number
#
# - You decide you want to play a game where you are hiding a number from someone. Store this number in a variable called 'answer'. Another user provides a number called 'guess'. By comparing guess to answer, you inform the user if their guess is too high or too low.
#
# - Fill in the conditionals below to inform the user about how their guess compares to the answer.

# %%
answer = 42
guess = 50

if guess < answer:
    print("Your guess is too low. Try again!")
elif guess > answer:
    print("Your guess is too high. Try again!")
else:
    print("Congratulations! You guessed the correct number!")
# Out:
# Your guess is too high. Try again!
